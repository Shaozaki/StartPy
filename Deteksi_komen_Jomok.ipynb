# %%
nama = input("Siapa namamu? : ")
print("Halo ", nama, type(nama))
# Out:
# Halo  Fatih <class 'str'>

# %%
tahun_lahir = input("Tahun berapa kamu lahir? ")
tahun_lahir = int(tahun_lahir)
umur = 2026 - tahun_lahir
print(umur)
# Out:
# 17

# %%
if (umur >= 17 ) :
    print(" Sudah Cukup Umur ")
else :
    print("Belum Cukup Umur")
# Out:
#  Sudah Cukup Umur

# %%
for i in range(5):
    print("Semangat Belajar")
# Out:
# Semangat Belajar
# Semangat Belajar
# Semangat Belajar
# Semangat Belajar
# Semangat Belajar

# %%
angka = 1
while angka <= 3:
    print(f"Putaran ke-{angka}")
    angka = angka + 1
# Out:
# Putaran ke-1
# Putaran ke-2
# Putaran ke-3

# %%
while True:
    tebakan = input("Sebutkan namaku: ")
    if tebakan == "Dormamu" :
        print(tebakan)
        break;
# Out:
# Dormamu

# %%
elders = ["Chameleos", "Kushala", "Teostra"]
print(elders[2])
# Out:
# Teostra

# %%
profile_wyvern = {
    "nama":"Lunagaron",
    "element": "Es",
    "Terbang" : False
}

print(profile_wyvern["nama"])
# Out:
# Lunagaron

# %%
def serang(nama_monster, damage):
    print(f"Memukul {nama_monster} sebesar {damage} damage!")

serang("Lunagaron", 150)
# Out:
# Memukul Lunagaron sebesar 150 damage!

# %%
def hitung_exp(level):
    return level * 100

my_exp = hitung_exp(5)
print(my_exp)
# Out:
# 500

# %%
base_attack = 100
def hitung_serangan(hp_sekarang):
    return hp_sekarang - base_attack

hp = 1000
serang = hitung_serangan(hp)
#print(serang)


while hp > 0 :
    hp = hitung_serangan(hp)
    print(hp)

if hp >= 0 :
    print("Rathalos Has ben slain")
# Out:
# 900
# 800
# 700
# 600
# 500
# 400
# 300
# 200
# 100
# 0
# Rathalos Has ben slain
